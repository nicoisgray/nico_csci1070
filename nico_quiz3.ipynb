# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
belize_listings_path = "belize_airbnb_listings.csv"
belize_df = pd.read_csv(belize_listings_path)
belize_df
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %%
neighbourhoods = belize_df.groupby('neighbourhood')
neighbourhoods.first()
# Out:
#                             id  \
# neighbourhood
# Belize Islands           36666
# Belize Mainland         265173
# Cayo                    152922
# Corozal                 736308
# Orange Walk            3594049
# Stann Creek Islands   18110861
# Stann Creek Mainland    110483
# Toledo Mainland         124794
#
#                                                                   name  \
# neighbourhood
# Belize Islands              Mo's Cozy Casa w/ veranda & access to dock
# Belize Mainland                          D'Nest Inn  ( Kiskadee Nest).
# Cayo                                    rent a private room in a house
# Corozal                   Beautiful Waterfront Casita! Belize is Open!
# Orange Walk           El Gran Mestizo premium romantic riverside cabin
# Stann Creek Islands          Belize Private Island- Little Peter Oasis
# Stann Creek Mainland                           Michelo's fuchsia suite
# Toledo Mainland                     Sabal Beach - secluded eco-retreat
#
# ...

# %%
nbh_price = neighbourhoods[['price']].mean()
nbh_price
# Out:
#                             price
# neighbourhood
# Belize Islands         399.442824
# Belize Mainland        288.273063
# Cayo                   205.847525
# Corozal                156.553846
# Orange Walk            122.035714
# Stann Creek Islands   1136.166667
# Stann Creek Mainland   456.994690
# Toledo Mainland        222.978723

# %%
nbh_reviews = neighbourhoods[['number_of_reviews']].sum()
nbh_reviews
# Out:
#                       number_of_reviews
# neighbourhood
# Belize Islands                    22995
# Belize Mainland                    4105
# Cayo                               7356
# Corozal                             492
# Orange Walk                         415
# Stann Creek Islands                  69
# Stann Creek Mainland               4786
# Toledo Mainland                     194

# %%
nbh_available = neighbourhoods[['availability_365']].max()
nbh_available
# Out:
#                       availability_365
# neighbourhood
# Belize Islands                     365
# Belize Mainland                    365
# Cayo                               365
# Corozal                            365
# Orange Walk                        365
# Stann Creek Islands                365
# Stann Creek Mainland               365
# Toledo Mainland                    365

# %%
nbh_partial = pd.merge(nbh_price, nbh_reviews, on=['neighbourhood'])
nbh_partial
# Out:
#                             price  number_of_reviews
# neighbourhood
# Belize Islands         399.442824              22995
# Belize Mainland        288.273063               4105
# Cayo                   205.847525               7356
# Corozal                156.553846                492
# Orange Walk            122.035714                415
# Stann Creek Islands   1136.166667                 69
# Stann Creek Mainland   456.994690               4786
# Toledo Mainland        222.978723                194

# %%
nbh_final = pd.merge(nbh_partial, nbh_available, on=['neighbourhood'])
nbh_final
# Out:
#                             price  number_of_reviews  availability_365
# neighbourhood
# Belize Islands         399.442824              22995               365
# Belize Mainland        288.273063               4105               365
# Cayo                   205.847525               7356               365
# Corozal                156.553846                492               365
# Orange Walk            122.035714                415               365
# Stann Creek Islands   1136.166667                 69               365
# Stann Creek Mainland   456.994690               4786               365
# Toledo Mainland        222.978723                194               365
